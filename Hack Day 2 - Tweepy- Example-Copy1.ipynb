# %%
# !pip install tweepy

# %%
import pandas as pd
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import time

# %%
class savetweepyTweets(StreamListener):

    def on_data(self, data):
        try:
            print (type(data))
            print ("New tweet")
            savefile = open('twittertrump1.txt','a')
            savefile.write(data)
            savefile.write('\n')
            savefile.close()
            return True
        except BaseException as e:
            print ("Failed ", str(e))
            self.disconnect()
    def on_error(self,status):
        print (status)
        stream.disconnect()
t1 = savetweepyTweets()
au = OAuthHandler('PPKMOVoSWNznuLfiMihLvOABl','5oqhSpcL3dBDScrgO4B3CR4jnJm2VYCiYLokJVAwrOXipzIe58')
au.set_access_token('1190775016897384450-M0fqedkcwVlpQD4G5Fz3X7DgAaP8iX','XGa6CgRpSyt7RpqSvWriQlJSLR63hRLgwiKS393LZdWQt')
stream = Stream(au,t1)

# %%
stream.filter(track=["trump"], languages=['en'])
# Out:
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# New tweet
# <class 'str'>
# ...

# %%
stream.disconnect()

# %%
import json
tweets_data = []
json_data = open('twittertrump1.txt','r')
#print type(json_data)
for line in json_data:
    #print type(line)
    try:
        twe = json.loads(line)
        #print type(twe)
        tweets_data.append(twe)
    except:
        continue

# %%
len(tweets_data)
# Out:
# 3296

# %%
tweet_df = pd.DataFrame(tweets_data)
tweet_df
# Out:
#       contributors  coordinates                      created_at  \
# 0              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 1              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 2              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 3              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 4              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 5              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 6              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 7              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 8              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 9              NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 10             NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 11             NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 12             NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# 13             NaN          NaN  Sun Nov 03 23:29:12 +0000 2019
# ...

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3296 entries, 0 to 3295
# Data columns (total 37 columns):
# contributors                 0 non-null float64
# coordinates                  0 non-null float64
# created_at                   3285 non-null object
# display_text_range           270 non-null object
# entities                     3285 non-null object
# extended_entities            163 non-null object
# extended_tweet               289 non-null object
# favorite_count               3285 non-null float64
# favorited                    3285 non-null object
# filter_level                 3285 non-null object
# geo                          0 non-null float64
# id                           3285 non-null float64
# id_str                       3285 non-null object
# in_reply_to_screen_name      277 non-null object
# in_reply_to_status_id        259 non-null float64
# in_reply_to_status_id_str    259 non-null object
# in_reply_to_user_id          277 non-null float64
# ...

# %%
pd.set_option('display.max_colwidth', 0)
tweet_df[["created_at","text"]]
# Out:
#                           created_at  \
# 0     Sun Nov 03 23:29:12 +0000 2019
# 1     Sun Nov 03 23:29:12 +0000 2019
# 2     Sun Nov 03 23:29:12 +0000 2019
# 3     Sun Nov 03 23:29:12 +0000 2019
# 4     Sun Nov 03 23:29:12 +0000 2019
# 5     Sun Nov 03 23:29:12 +0000 2019
# 6     Sun Nov 03 23:29:12 +0000 2019
# 7     Sun Nov 03 23:29:12 +0000 2019
# 8     Sun Nov 03 23:29:12 +0000 2019
# 9     Sun Nov 03 23:29:12 +0000 2019
# 10    Sun Nov 03 23:29:12 +0000 2019
# 11    Sun Nov 03 23:29:12 +0000 2019
# 12    Sun Nov 03 23:29:12 +0000 2019
# 13    Sun Nov 03 23:29:12 +0000 2019
# 14    Sun Nov 03 23:29:12 +0000 2019
# 15    Sun Nov 03 23:29:12 +0000 2019
# 16    Sun Nov 03 23:29:12 +0000 2019
# 17    Sun Nov 03 23:29:12 +0000 2019
# 18    Sun Nov 03 23:29:12 +0000 2019
# 19    Sun Nov 03 23:29:12 +0000 2019
# 20    Sun Nov 03 23:29:12 +0000 2019
# 21    Sun Nov 03 23:29:12 +0000 2019
# 22    Sun Nov 03 23:29:12 +0000 2019
# 23    Sun Nov 03 23:29:12 +0000 2019
# ...
